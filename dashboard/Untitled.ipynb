# %%
import dash
import dash_bootstrap_components as dbc
import dash_html_components as html
import dash_core_components as dcc
import plotly.express as px
from dash.dependencies import Input, Output
import pandas as pd

# data source: https://www.kaggle.com/chubak/iranian-students-from-1968-to-2017
# data owner: Chubak Bidpaa
df = pd.read_csv('https://raw.githubusercontent.com/Coding-with-Adam/Dash-by-Plotly/master/Bootstrap/Side-Bar/iranian_students.csv')

app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])


# styling the sidebar
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "16rem",
    "padding": "2rem 1rem",
    "background-color": "#f8f9fa",
}

# padding for the page content
CONTENT_STYLE = {
    "margin-left": "18rem",
    "margin-right": "2rem",
    "padding": "2rem 1rem",
}

sidebar = html.Div(
    [
        html.H2("Sidebar", className="display-4"),
        html.Hr(),
        html.P(
            "Number of students per education level", className="lead"
        ),
        dbc.Nav(
            [
                dbc.NavLink("Coleta", href="/", active="exact"),
                dbc.NavLink("Desenvolvimento", href="/page-1", active="exact"),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
)

content = html.Div(id="page-content", children=[], style=CONTENT_STYLE)

app.layout = html.Div([
    dcc.Location(id="url"),
    sidebar,
    content
])


@app.callback(
    Output("page-content", "children"),
    [Input("url", "pathname")]
)
def render_page_content(pathname):
    if pathname == "/":
        return [
                html.H1('Kindergarten in Iran',
                        style={'textAlign':'center'}),
                dcc.Graph(id='bargraph',
                         figure=px.bar(df, barmode='group', x='Years',
                         y=['Girls Kindergarten', 'Boys Kindergarten']))
                ]
    elif pathname == "/page-1":
        return [
                html.H1('Grad School in Iran',
                        style={'textAlign':'center'}),
                dcc.Graph(id='bargraph',
                         figure=px.bar(df, barmode='group', x='Years',
                         y=['Girls Grade School', 'Boys Grade School']))
                ]

    # If the user tries to reach a different page, return a 404 message
    return dbc.Jumbotron(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ]
    )


if __name__ == '__main__':
    app.run_server(port=8051)
# Out:
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8051/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Feb/2022 11:16:21] "GET /page-2 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:21] "GET /assets/s1.css?m=1639767020.204345 HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2022 11:16:22] "GET /assets/resizing_script.js?m=1639767019.4372773 HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2022 11:16:22] "GET /assets/styles.css?m=1642692115.5071099 HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Feb/2022 11:16:23] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:23] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:23] "GET /_favicon.ico?v=2.0.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:24] "GET /_favicon.ico?v=2.0.0 HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash/dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-3-0f2262bf8637>", line 85, in render_page_content
#     return dbc.Jumbotron(
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash_bootstrap_components/__init__.py", line 52, in __getattr__
#     f"{name} was deprecated in dash-bootstrap-components version "
# AttributeError: Jumbotron was deprecated in dash-bootstrap-components version 1.0.0. You are using 1.0.1. For more details please see the migration guide: https://dash-bootstrap-components.opensource.faculty.ai/migration-guide/
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash/dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-3-0f2262bf8637>", line 85, in render_page_content
#     return dbc.Jumbotron(
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash_bootstrap_components/__init__.py", line 52, in __getattr__
#     f"{name} was deprecated in dash-bootstrap-components version "
# AttributeError: Jumbotron was deprecated in dash-bootstrap-components version 1.0.0. You are using 1.0.1. For more details please see the migration guide: https://dash-bootstrap-components.opensource.faculty.ai/migration-guide/
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/flask/app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash/dash.py", line 1336, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash/_callback.py", line 151, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#   File "<ipython-input-3-0f2262bf8637>", line 85, in render_page_content
#     return dbc.Jumbotron(
#   File "/dados01/workspace/ufmg_2021_f01/ufmg.cmikaela/.local/lib/python3.6/site-packages/dash_bootstrap_components/__init__.py", line 52, in __getattr__
#     f"{name} was deprecated in dash-bootstrap-components version "
# AttributeError: Jumbotron was deprecated in dash-bootstrap-components version 1.0.0. You are using 1.0.1. For more details please see the migration guide: https://dash-bootstrap-components.opensource.faculty.ai/migration-guide/
# 127.0.0.1 - - [22/Feb/2022 11:16:24] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [22/Feb/2022 11:16:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:26] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:26] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Feb/2022 11:16:31] "POST /_dash-update-component HTTP/1.1" 200 -
